# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import forgi.utilities.debug as fud

import pandas as pa

def load_raw_interactions(filename):
    t = pa.read_csv(filename, header=None, sep=' ')
    t.columns = ['key1', 'type1', 'len1', 'key2', 'type2', 
                 'len2', 'dist', 'seq1', 'seq2', 'longrange', 'angle']
    
    return t

# %%
t = load_raw_interactions('fess/stats/temp.longrange.stats')

# %%
ty = t[t.longrange == 'Y']
tn = t[t.longrange == 'N']

# %%
tyhi = ty[np.logical_and(ty.type1 == 'h', np.logical_or(ty.type2 == 'i', ty.type2 == 's'))]
tnhi = tn[np.logical_and(tn.type1 == 'h', np.logical_or(tn.type2 == 'i', tn.type2 == 's'))]
#tyhi = ty[np.logical_and(ty.type1 == 'h', ty.type2 == 'i')]
#tnhi = tn[np.logical_and(tn.type1 == 'h', tn.type2 == 'i')]

# %%
hist(tyhi.len1)
# Out:
# (array([ 1, 12, 10,  7,  0, 10,  5,  4,  1,  3]),
#  array([  3. ,   3.8,   4.6,   5.4,   6.2,   7. ,   7.8,   8.6,   9.4,
#         10.2,  11. ]),
#  <a list of 10 Patch objects>)

# %%
hist(tnhi.len1)
# Out:
# (array([1220,  487, 6078, 2189, 2918, 1943,  243,  241,  244,  244]),
#  array([  1. ,   2.4,   3.8,   5.2,   6.6,   8. ,   9.4,  10.8,  12.2,
#         13.6,  15. ]),
#  <a list of 10 Patch objects>)

# %%
hist(tyhi.dist)
# Out:
# (array([1, 0, 1, 0, 0, 1, 1, 0, 0, 3]),
#  array([  2.548006 ,   4.5504369,   6.5528678,   8.5552987,  10.5577296,
#         12.5601605,  14.5625914,  16.5650223,  18.5674532,  20.5698841,
#         22.572315 ]),
#  <a list of 10 Patch objects>)

# %%
hist(tyhi.angle)
# Out:
# (array([1, 0, 1, 0, 0, 3, 1, 0, 0, 1]),
#  array([ 0.350207 ,  0.5733996,  0.7965922,  1.0197848,  1.2429774,
#         1.46617  ,  1.6893626,  1.9125552,  2.1357478,  2.3589404,
#         2.582133 ]),
#  <a list of 10 Patch objects>)

# %%
import numpy as np

mu_vec1 = np.array([0,0])
cov_mat1 = np.array([[2,0],[0,2]])
x1_samples = np.random.multivariate_normal(mu_vec1, cov_mat1, 100)
mu_vec1 = mu_vec1.reshape(1,2).T # to 1-col vector

mu_vec2 = np.array([1,2])
cov_mat2 = np.array([[1,0],[0,1]])
x2_samples = np.random.multivariate_normal(mu_vec2, cov_mat2, 100)
mu_vec2 = mu_vec2.reshape(1,2).T

# %%
def decision_boundary(x_vec, mu_vec1, mu_vec2):
    g1 = (x_vec-mu_vec1).T.dot((x_vec-mu_vec1))
    g2 = 2*( (x_vec-mu_vec2).T.dot((x_vec-mu_vec2)) )
    return g1 - g2

# %%
print mu_vec1
# Out:
# [[0]
#  [0]]

# %%
plot(x1_samples[:,0], x1_samples[:,1], '.')
plot(x2_samples[:,0], x2_samples[:,1], '.')

# %%
x_vec = [-1,0,1,2,3,4,5,6,7]
db = decision_boundary(x_vec, mu_vec1, mu_vec2)
print db
# Out:
# [[-24 -16  -8   0   8  16  24  32  40]
#  [-16 -10  -4   2   8  14  20  26  32]
#  [ -8  -4   0   4   8  12  16  20  24]
#  [  0   2   4   6   8  10  12  14  16]
#  [  8   8   8   8   8   8   8   8   8]
#  [ 16  14  12  10   8   6   4   2   0]
#  [ 24  20  16  12   8   4   0  -4  -8]
#  [ 32  26  20  14   8   2  -4 -10 -16]
#  [ 40  32  24  16   8   0  -8 -16 -24]]

# %%
plot(x1_samples[:,0], x1_samples[:,1], '.')
plot(x2_samples[:,0], x2_samples[:,1], '.')
plot(x_vec, db)
# Out:
# [<matplotlib.lines.Line2D at 0x3708f50>,
#  <matplotlib.lines.Line2D at 0x370a5d0>,
#  <matplotlib.lines.Line2D at 0x370a750>,
#  <matplotlib.lines.Line2D at 0x370a8d0>,
#  <matplotlib.lines.Line2D at 0x370aa50>,
#  <matplotlib.lines.Line2D at 0x370abd0>,
#  <matplotlib.lines.Line2D at 0x370ad50>,
#  <matplotlib.lines.Line2D at 0x370aed0>,
#  <matplotlib.lines.Line2D at 0x3532310>]
